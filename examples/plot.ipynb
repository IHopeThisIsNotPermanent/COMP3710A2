# %%
import matplotlib.pyplot as plt

# %%
len(acc1 + acc2)
# Out:
# 25

# %%
bc1 = [10,    25,    35,    45,    55,    65,    75,    80,    90,    100,   115,   130,   150,   175,   200]
acc1 = [62.78, 69.63, 70.75, 69.18, 69.38, 70.78, 70.21, 68.78, 69.13, 69.07, 67.76, 67.14, 67.21, 65.67, 64.32]
t1 = [47.76, 21.20, 16.48, 13.87, 12.59, 11.89, 11.64, 11.44, 11.21, 11.09, 10.90, 10.57, 10.42, 10.16, 10.20]

bc2 = [55,    57,    59,    61,    62,    64,    66,    68,    70]
acc2 = [70.27, 68.16, 69.35, 69.44, 68.80, 68.28, 69.86, 70.09, 66.82]
t2 = [12.64, 12.50, 12.67, 12.37, 12.30, 12.02, 11.87, 11.87, 11.57]

plt.scatter(bc1 + bc2, acc1 + acc2, label = 'accuracy')
plt.scatter(bc1 + bc2, t1 + t2, label = 'timing')

plt.legend()

plt.plot()
# Out:
# []
